# %%
 s =set()
 s1 = {}
 print(type(s),type(s1))
 print(s,s1)
# Out:
# <class 'set'> <class 'dict'>
# set() {}

# %%
s.add(10)
print(s)
# Out:
# {10}

# %%
s.update([10,20,30,40])
s.update
print(s)
# Out:
# {40, 10, 20, 30}

# %%
print(s.pop())
# Out:
# 40

# %%
s.clear()
print(s)
# Out:
# set()

# %%
s1 = {1,2,3,4,57,6,7,89}
print(s1)
# Out:
# {1, 2, 3, 4, 6, 7, 89, 57}

# %%
del s

# %%
s1 ={20,30,40,80}
s2 ={10,30,50,70}
print(s1.union(s2))
print(s1 | s2)
# Out:
# {70, 40, 10, 80, 50, 20, 30}
# {70, 40, 10, 80, 50, 20, 30}

# %%
print(s1.intersection(s2))
print(s1&s2)
# Out:
# {30}
# {30}

# %%
print(s1.difference(s2))
print(s1-s2)
# Out:
# {40, 80, 20}
# {40, 80, 20}

# %%
print(s1.symmetric_difference(s2))
print(s1 ^ s2)
# Out:
# {70, 40, 10, 80, 50, 20}
# {70, 40, 10, 80, 50, 20}

# %%
s1 = {1,3,4,5,6}
s2 = {2,4,6,8,9}
print(s1.issubset(s2))
print(s2.issubset(s1))
# Out:
# False
# False

# %%
 d = {}
 d1 = dict()
 details ={"name":"codegnan":"branch":"hyderabad","batch":"PFS66","no_students":51}
 print(type(d),type(1))
# Out:
#   Cell In[25], line 3
#     details ={"name":"codegnan":"branch":"hyderabad","batch":"PFS66","no_students":51}
#                                ^
# SyntaxError: invalid syntax

# %%
print(details.keys())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 print(details)
#
# NameError: name 'details' is not defined

# %%
print(details.values())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 print(details.values())
#
# NameError: name 'details' is not defined

# %%
print(details.items())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 print(details.items())
#
# NameError: name 'details' is not defined

# %%
#unpacking
t = (1,2,3,4)
print(t)
# Out:
# (1, 2, 3, 4)

# %%
print(*t)
# Out:
# 1 2 3 4

# %%
print()
