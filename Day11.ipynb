# %%
n = 987
total = 0
while n>0:
    digit = n%10
    total = total+digit
    print(total)
    n= n//10
# Out:
# 7
# 15
# 24

# %%
n =234
string =str(n)
print(type(n))
print(type(string))
# Out:
# <class 'int'>
# <class 'str'>

# %%
name = "Naveen"
for ch in name:
    print(ch)
# Out:
# N
# a
# v
# e
# e
# n

# %%
n =286
total = 0
string =str(n)
for num in string:
    total = total+int(num)
print(total)
# Out:
# 16

# %%
string = "abcdefg"
result = " "
for s in string:
    result+=s.upper()
print(result)
# Out:
#  ABCDEFG

# %%
s1 = "hfhf"
s2 = "erty"
print(s1+s2)
# Out:
# hfhferty
