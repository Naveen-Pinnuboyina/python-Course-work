# %%
number = int(input())
if number>0:
   print("positive")
# Out:
# 4
# positive

# %%
# if else
age = int(input())
if age>=18:
    print("you are eligible")
else:
    print("you are not eligible")
# Out:
# 17
# you are not eligible

# %%
# if elif
marks = int(input())
if marks>=90:
    print("A grade")
elif marks>=75:
    print("B grade")
elif marks>=50:
    print("C grade")
elif marks>=35:
    print("D grade")
else:
    print("Fail")

# %%
# if elif
marks = int(input())
if marks>=90:
    print("A grade")
elif marks>=75:
    print("B grade")
elif marks>=50:
    print("C grade")
elif marks>=35:
    print("D grade")
else:
    print("Fail")

# %%
 m = int(input())
if m>50:
    print("random number")
elif m>90:
    print("number grearer than 90")
