# %%
print("python programming")
# Out:
# python programming

# %%
my_number = 8
my_number = 28
number1 = 9
number2 = 7
print(number1)
print(my_number)
# Out:
# 9
# 28

# %%
my_name = "Naveen"
print(my_name)
# Out:
# Naveen

# %%
x,y = 20,30
print(x,y)
print("before swapping", x,y)
# Out:
# 20 30
# before swapping 20 30

# %%
# Swapping using the temporary varible
x,y = 20,30
print(x,y)
temp = x
x = y
y = temp
print(x,y)
# Out:
# 20 30
# 30 20

# %%
x,y = 200, 400
print(x,y)
x,y = y,x
print(x,y)
# Out:
# 200 400
# 400 200
