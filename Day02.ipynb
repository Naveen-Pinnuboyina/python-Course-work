# %%
#Arthimetical operators
a=200
b=100
print(a+b)
print(a-b)
print(a*b)
print(a%b)
print(a//b)
print(a/b)
print(3**4)

# %%
a = int(input())
print(a)

# %%
a,b = 1,3
print(a,b)

# %%
a,b = map(int,input().split(" "))
print(a,b)

# %%
# assignment
a=200
b=100
a=a + 100 #a+=100
b-=100
print(b*=100)
print(a)

# %%
# comparsion
a = 28
b = 45
print(a>b)
print(a<b)
print(a<=b)
print(a>=b)
print(a==b)
print(a!=b)

# %%
# logical
print(a>b and a>b)
print(a<=b and a!=b)
print(a==26) and b>=a)
print()
print(a<b or a>b)
print(a<=b or a!=b)
print(a>b)

# %%
#betwise 
print(6 & 4)
print(6 |4)
print(6 ^ 4)
print(4<<3)
print(8>>1)

# %%
#Membership
l1 = [10,20,30]
l2 = [10,20,30]
l3 = l1
print(l1 is l2)
print(l1 is l3)
print(l1==l2)
